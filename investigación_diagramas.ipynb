# %% [markdown]
# ###HISTORIGRAMA
#
# Un historigrama es mayormente un grafico que representa la distribución de datos cuantitativos ![image.png](data:image/png;base64,...)
#
#
#
#
# Esta mayormente consiste en barras para representar la frecuencia o las veces que el dato o elemento cae dentro de un rango especifico
#
# ¿Como se crean?
# El paso principal para crear un historigráma es a través de la obtención de datos numericos en un rango que se quiera analizar
#
# ¿Como son?
#
# Estas se diferencian de un gráfico de barras mediante la inexistente separación en estas, y que el ancho no cambia de nada
#
# ¿Para que sirven?
#
# estas ayudan a identificar patrones, como la conservación o dispersión de los datos. Y para poder tomar decisiones mediante su tipo de distribución
#
# ¿En que contexto se utilizan?
# 1.Estadistica
# *Resumir grandes conjuntos de datos y analizar tendencias
# 2.Ciencias sociales
# *Investigar el comportamiento de ciertos eventos o patrones poblacionales
# 3.Economia o negocioes
# *Evalluación de ventas, ingresos y valores del mercado

# %% [markdown]
# ###DIAGRAMA DE TALLO Y HOJA
#
# Herramienta gráfica que organiza y representa datos numéricos en forma de texto . Estas dividen la sección del tallo y de la hoja para proporcionar una vista rapida a su distribución
#
# ![image.png](data:image/png;base64,...)
#
# ¿Como se crean?
#
# mediante la recolección de datos se obtiene una lista de numeros con los valores que representan. estos son separados en tallos (cifras mas significativas) y la hoja corresponde las menos significativas (unidades mas pequeñas)
#
# ¿Como son?
#
# Estas usan una estructura tabular dividida en dos columnas, donde la primera muestra los tallos y la segunda las hojas
#
# ¿Para que sirven?
#
# Sirven para hacer analisis de datos pequeños o incluso medianos, y observar rapidamente patrones y tendencias, también que pueden ser parte para formar un historigrama
#
# ¿En que contexto se utilizan?
#
# 1.Estadistica descriptiva
# resumir datos
#
# 2.Educación
#
# herramienta pedagógica para conceptos basicos
#
# 3.Investigación cientifica
#
# representar mediciones o datos recolectados en experimentos y pruebas anteriores

# %% [markdown]
# ###DIAGRAMA DE CAJA
#
# Es una representación gráfica que resume la distribución de un conjunto de datos mediante cinco medidas principales: minimo,primer cuartil, mediana, tercer cuartil y maximo.
#
# ![image.png](data:image/png;base64,...)
#
#
# ¿Como se crean?
#
# Los datos que se recopilan mediante la recolección de datos, se organizan en orden ascendente cada parte del diagrama tiene una función
# Minimo:valor mas pequeño del conjunto de datos
# Primer cuartil: el 25% inferior a los dato
# Mediana: el 50% que separa los datos en dos mitades iguales
# tercer cuartil: el 25% superior a los datos
# maximo: el valor mas grande del conjunto de los datos recolectados
#
# ¿Como son?
#
# una caja rectangular que abarca desde Q1  a Q3
# Una caja dentro de la caja que indica la mediana
# Y lo que se puede identificar  en la imagen de arriba
#
# ¿Para que sirven?
#
# 1.Estadistica descriptiva
#
# analizar la distribución de datos cuantitativos
#
# 2.Analisis exploratorio de datos
#
# proporcionar una vision inicial de las caracteristicas de los datos
